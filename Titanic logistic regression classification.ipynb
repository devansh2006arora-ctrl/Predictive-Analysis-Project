# %% [markdown]
# TITANIC DATASET FOR LOGISTIC REGRESSION CLASSIFICATION

# %%
import os

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings. filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin'

# %%
pwd
# Out:
# 'C:\\Users\\admin'

# %%
os.chdir('C:\\Users\\admin')

# %%
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.mamba',
#  '.matplotlib',
#  '.ms-ad',
#  '.virtual_documents',
#  '27.07.2026.ipynb',
#  '28.07.2026.ipynb',
#  '3D Objects',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'Benison Supermarket customer journey analysis.ipynb',
#  'Benison_Analysis_Report.html',
#  'bluej',
#  'carbon_reduction_2030.png',
#  'cement_industry_analysis.png',
#  'cement_industry_analysis_christ.png',
#  'Cement_Industry_Analysis_Figure1.png',
#  'cement_industry_final.png',
#  'cement_industry_growth_market_share.png',
#  'cement_industry_visualization.png',
#  'chart1_journey_stage_funnel.png',
#  'chart2_interaction_score_heatmap.png',
#  'chart3_repeat_info_score_comparison.png',
#  'Coca-Cola 2022-2023 Retail Performance Dashboard.ipynb',
#  'coca_cola_analysis.xlsx',
#  'coca_cola_dashboard_20251226_194725.csv',
#  'coca_cola_dashboard_20251226_194725.json',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'insights_report.txt',
#  'INTERNSHIP',
#  'IRP.ipynb',
#  'KHUSHI PATEL (2423231) 4BBA SBA A Simple Linear Regression Case Study Hands on Application.ipynb',
#  'KHUSHI PATEL 2423231.ipynb',
#  'Khushi(2423231),Devansh(2423217),Naman(2423244),Ankit(2423207).ipynb',
#  'Links',
#  'Local Settings',
#  'M.A..ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{7a0e9da1-c934-11ef-9343-d6e45149f922}.TM.blf',
#  'NTUSER.DAT{7a0e9da1-c934-11ef-9343-d6e45149f922}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{7a0e9da1-c934-11ef-9343-d6e45149f922}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'positioning_matrix_2030.png',
#  'Predictive Analysis .ipynb',
#  'prem',
#  'PrintHood',
#  'Recent',
#  'revenue_2030.png',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Simple Linear Regression Case Study Hands on Application.ipynb',
#  'Start Menu',
#  'Templates',
#  'Tracing',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled45.ipynb',
#  'Untitled46.ipynb',
#  'Untitled47.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Videos',
#  'Visualization Hands on Application.ipynb']

# %% [markdown]
# LOADING DATA AND UNDERSTANDING THE DATA

# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\admin\Downloads\train.xlsx")
X_test =pd.read_excel(r"C:\Users\admin\Downloads\test.xlsx")
Y_test =pd.read_excel(r"C:\Users\admin\Downloads\gender_submission.xlsx")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
X_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
Y_test
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
PassengerId =X_test['PassengerId']

# %%
PassengerId.head()
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# Name: PassengerId, dtype: int64

# %%
print ('X_train')
df.info()
print('-'*70)
print ('X_test')
X_test.info()
# Out:
# X_train
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ----------------------------------------------------------------------
# X_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x='Survived',data=df,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
fig, ax = plt. subplots (1, 2, figsize=(18, 6))
sns. barplot (data=df, x='Pclass', y='Survived', hue='Sex', ax=ax [0])
ax [0]. set_title('Survival Rate by Class and Sex')
ax [0]. set_ylabel ('Mean Survival Rate')
sns.histplot (data=df, x='Age', hue='Survived', kde=True, bins=30, element='step', ax=ax[1])
ax[1]. set_title('Age Distribution by Survival')
plt. tight_layout()
plt.show()

# %%
f,ax=plt.subplots (1,2, figsize=(18,8))
df['Survived']. value_counts(). plot. pie(explode=[0, 0.1], autopct = '%1.1f%%',ax=ax[0], shadow=True) 
ax[0].set_title ('Survived') 
ax[0].set_ylabel ('') 
sns. countplot(x = 'Survived', data=df, ax=ax[1]) 
ax[1].set_title ('Survived') 
plt.show()

# %%
df['Initial']=0
for i in df.Name:
    df['Initial']=df.Name.str.extract('([A-Za-z]+)\.')

# %%
X_test['Initial']=0
for i in X_test.Name:
    X_test['Initial']=X_test.Name.str.extract('([A-Za-z]+)\.')

# %%
df['Initial'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
X_test['Initial'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_b9d43_row0_col0, #T_b9d43_row0_col1, #T_b9d43_row0_col3, #T_b9d43_row0_col4, #T_b9d43_row0_col5, #T_b9d43_row0_col7, #T_b9d43_row0_col8, #T_b9d43_row0_col12, #T_b9d43_row0_col15, #T_b9d43_row0_col16, #T_b9d43_row1_col2, #T_b9d43_row1_col6, #T_b9d43_row1_col9, #T_b9d43_row1_col10, #T_b9d43_row1_col11, #T_b9d43_row1_col13, #T_b9d43_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b9d43_row0_col2, #T_b9d43_row0_col6, #T_b9d43_row0_col9, #T_b9d43_row0_col10, #T_b9d43_row0_col11, #T_b9d43_row0_col13, #T_b9d43_row0_col14, #T_b9d43_row1_col0, #T_b9d43_row1_col1, #T_b9d43_row1_col3, #T_b9d43_row1_col4, #T_b9d43_row1_col5, #T_b9d43_row1_col7, #T_b9d43_row1_col8, #T_b9d43_row1_col12, #T_b9d43_row1_col15, #T_b9d43_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b9d43">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_b9d43_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_b9d43_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_b9d43_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_b9d43_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_b9d43_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_b9d43_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_b9d43_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_b9d43_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_b9d43_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_b9d43_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_b9d43_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_b9d43_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_b9d43_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_b9d43_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_b9d43_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_b9d43_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_b9d43_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9d43_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_b9d43_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b9d43_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b9d43_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_b9d43_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b9d43_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_b9d43_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b9d43_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_b9d43_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_b9d43_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_b9d43_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_b9d43_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_b9d43_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_b9d43_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_b9d43_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_b9d43_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_b9d43_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_b9d43_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b9d43_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_b9d43_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b9d43_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_b9d43_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b9d43_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_b9d43_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_b9d43_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_b9d43_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_b9d43_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_b9d43_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_b9d43_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_b9d43_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_b9d43_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_b9d43_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_b9d43_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_b9d43_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_b9d43_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_b9d43_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
df['Pclass'].replace([1,2,3],['first','second','third'],inplace=True)
X_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mrs'],inplace=True)
X_test['Pclass'].replace([1,2,3],['first','second','third'],inplace=True)

# %%
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8eab4_row0_col0, #T_8eab4_row0_col2, #T_8eab4_row0_col4, #T_8eab4_row1_col1, #T_8eab4_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_8eab4_row0_col1, #T_8eab4_row0_col3, #T_8eab4_row1_col0, #T_8eab4_row1_col2, #T_8eab4_row1_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8eab4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_8eab4_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_8eab4_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_8eab4_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_8eab4_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_8eab4_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eab4_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_8eab4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8eab4_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_8eab4_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_8eab4_row0_col3" class="data row0 col3" >127</td>
#       <td id="T_8eab4_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8eab4_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_8eab4_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_8eab4_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8eab4_row1_col2" class="data row1 col2" >528</td>
#       <td id="T_8eab4_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_8eab4_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(X_test.Initial,X_test.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5da48_row0_col0, #T_5da48_row0_col2, #T_5da48_row0_col4, #T_5da48_row1_col1, #T_5da48_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5da48_row0_col1, #T_5da48_row0_col3, #T_5da48_row1_col0, #T_5da48_row1_col2, #T_5da48_row1_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5da48">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_5da48_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_5da48_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_5da48_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_5da48_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_5da48_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5da48_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_5da48_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5da48_row0_col1" class="data row0 col1" >79</td>
#       <td id="T_5da48_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_5da48_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_5da48_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5da48_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_5da48_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_5da48_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5da48_row1_col2" class="data row1 col2" >241</td>
#       <td id="T_5da48_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_5da48_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='Pclass',y='Survived',col='Initial',data=df,kind='point',height=4,aspect=0.9)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x='Sex',hue='Survived',data=df,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
df.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
X_test.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     7.406471
# Miss      21.774844
# Mr        32.114130
# Mrs       38.904762
# Other     42.750000
# Name: Age, dtype: float64

# %%
df.loc[(df.Age.isnull())&(df.Initial=='Master'),'Age']=5
df.loc[(df.Age.isnull())&(df.Initial=='Miss'),'Age']=22
df.loc[(df.Age.isnull())&(df.Initial=='Mr'),'Age']=33
df.loc[(df.Age.isnull())&(df.Initial=='Mrs'),'Age']=36
df.loc[(df.Age.isnull())&(df.Initial=='Other'),'Age']=46

# %%
X_test.loc[(X_test.Age.isnull())&(X_test.Initial=='Master'),'Age']=5
X_test.loc[(X_test.Age.isnull())&(X_test.Initial=='Miss'),'Age']=22
X_test.loc[(X_test.Age.isnull())&(X_test.Initial=='Mr'),'Age']=33
X_test.loc[(X_test.Age.isnull())&(X_test.Initial=='Mrs'),'Age']=36
X_test.loc[(X_test.Age.isnull())&(X_test.Initial=='Other'),'Age']=46

# %%
df.Initial.isnull().any()
# Out:
# False

# %%
X_test.Initial.isnull().any()
# Out:
# False

# %%
print('X_train')
df.info()
print('-'*70)
print('X_test')
X_test.info()
# Out:
# X_train
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Initial      891 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 90.6+ KB
# ----------------------------------------------------------------------
# X_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    object
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  Initial      418 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 39.3+ KB

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f7540_row0_col0, #T_f7540_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_f7540_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_f7540_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_f7540_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_f7540_row0_col4, #T_f7540_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_f7540_row1_col0, #T_f7540_row3_col0, #T_f7540_row3_col1, #T_f7540_row3_col2, #T_f7540_row3_col3, #T_f7540_row3_col4, #T_f7540_row4_col0, #T_f7540_row4_col2, #T_f7540_row4_col3, #T_f7540_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f7540_row1_col1, #T_f7540_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_f7540_row1_col3, #T_f7540_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_f7540_row2_col0, #T_f7540_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_f7540_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_f7540_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_f7540_row2_col4, #T_f7540_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_f7540_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_f7540_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_f7540_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_f7540_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_f7540_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_f7540_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_f7540_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_f7540_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_f7540_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_f7540_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_f7540_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_f7540_row7_col3, #T_f7540_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_f7540_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_f7540_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_f7540_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_f7540_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_f7540_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_f7540_row9_col0, #T_f7540_row9_col1, #T_f7540_row9_col2, #T_f7540_row9_col3, #T_f7540_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7540">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_f7540_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_f7540_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_f7540_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_f7540_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_f7540_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_f7540_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_f7540_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_f7540_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7540_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_f7540_level1_row0" class="row_heading level1 row0" >first</th>
#       <td id="T_f7540_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f7540_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_f7540_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_f7540_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_f7540_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row1" class="row_heading level1 row1" >second</th>
#       <td id="T_f7540_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f7540_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_f7540_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_f7540_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_f7540_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row2" class="row_heading level1 row2" >third</th>
#       <td id="T_f7540_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_f7540_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_f7540_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_f7540_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_f7540_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_f7540_level1_row3" class="row_heading level1 row3" >first</th>
#       <td id="T_f7540_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f7540_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f7540_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_f7540_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_f7540_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row4" class="row_heading level1 row4" >second</th>
#       <td id="T_f7540_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_f7540_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_f7540_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_f7540_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_f7540_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row5" class="row_heading level1 row5" >third</th>
#       <td id="T_f7540_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_f7540_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_f7540_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_f7540_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_f7540_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_f7540_level1_row6" class="row_heading level1 row6" >first</th>
#       <td id="T_f7540_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_f7540_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_f7540_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_f7540_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_f7540_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row7" class="row_heading level1 row7" >second</th>
#       <td id="T_f7540_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_f7540_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_f7540_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_f7540_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_f7540_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level1_row8" class="row_heading level1 row8" >third</th>
#       <td id="T_f7540_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_f7540_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_f7540_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_f7540_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_f7540_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_f7540_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_f7540_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_f7540_row9_col0" c

# %%
df["Embarked"].fillna("S",inplace=True)
X_test["Embarked"].fillna("S",inplace=True)

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Initial'],
#       dtype='object')

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0  second                     Montvila, Rev. Juozas
# 887          888         1   first              Graham, Miss. Margaret Edith
# 888          889         0   third  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1   first                     Behr, Mr. Karl Howell
# 890          891         0   third                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked Initial
# 886    male  27.0      0      0      211536  13.00   NaN        S   Other
# 887  female  19.0      0      0      112053  30.00   B42        S    Miss
# 888  female  22.0      1      2  W./C. 6607  23.45   NaN        S    Miss
# 889    male  26.0      0      0      111369  30.00  C148        C      Mr
# 890    male  32.0      0      0      370376   7.75   NaN        Q      Mr

# %% [markdown]
# Creating new feature by appending 'Parch'and 'SibSp'

# %%
df['FamilySize']= df['Parch']+df['SibSp']
X_test['FamilySize']= X_test['Parch']+ X_test['SibSp']

# %% [markdown]
# DATA CLEANING

# %%
data=df.drop(['PassengerId','Name','Cabin','Ticket','Parch','SibSp'],axis=1)
X_test=X_test.drop(['PassengerId','Name','Cabin','Ticket','Parch','SibSp'],axis=1)

# %%
data.head()
# Out:
#    Survived Pclass     Sex   Age     Fare Embarked Initial  FamilySize
# 0         0  third    male  22.0   7.2500        S      Mr           1
# 1         1  first  female  38.0  71.2833        C     Mrs           1
# 2         1  third  female  26.0   7.9250        S    Miss           0
# 3         1  first  female  35.0  53.1000        S     Mrs           1
# 4         0  third    male  35.0   8.0500        S      Mr           0

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Embarked      0
# Initial       0
# FamilySize    0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age           0
# Fare          1
# Embarked      0
# Initial       0
# FamilySize    0
# dtype: int64

# %%
data.FamilySize.unique()
# Out:
# array([ 1,  0,  4,  2,  6,  5,  3,  7, 10], dtype=int64)

# %%
data.FamilySize.value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_634a4_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_634a4_row1_col0 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_634a4_row2_col0 {
#   background-color: #2e9666;
#   color: #f1f1f1;
# }
# #T_634a4_row3_col0 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_634a4_row4_col0 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_634a4_row5_col0 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_634a4_row6_col0 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# #T_634a4_row7_col0, #T_634a4_row8_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_634a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_634a4_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FamilySize</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_634a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_634a4_row0_col0" class="data row0 col0" >537</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_634a4_row1_col0" class="data row1 col0" >161</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_634a4_row2_col0" class="data row2 col0" >102</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_634a4_row3_col0" class="data row3 col0" >29</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_634a4_row4_col0" class="data row4 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_634a4_row5_col0" class="data row5 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_634a4_row6_col0" class="data row6 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_634a4_row7_col0" class="data row7 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_634a4_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_634a4_row8_col0" class="data row8 col0" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ONE HOT ENCODING

# %%
data=pd.get_dummies(data)
X_test=pd.get_dummies(X_test)

# %%
data["Age"]=((data["Age"]-data["Age"].min())/(data["Age"].max()-data["Age"].min()))
data["Fare"]=((data["Fare"]-data["Fare"].min())/(data["Fare"].max()-data["Fare"].min()))
data["FamilySize"]=((data["FamilySize"]-data["FamilySize"].min())/(data["FamilySize"].max()-data["FamilySize"].min()))

# %%
X_test["Age"]=((X_test["Age"]-X_test["Age"].min())/(X_test["Age"].max()-X_test["Age"].min()))
X_test["Fare"]=((X_test["Fare"]-X_test["Fare"].min())/(X_test["Fare"].max()-X_test["Fare"].min()))
X_test["FamilySize"]=((X_test["FamilySize"]-X_test["FamilySize"].min())/(X_test["FamilySize"].max()-X_test["FamilySize"].min()))

# %%
data.head()
# Out:
#    Survived       Age      Fare  FamilySize  Pclass_first  Pclass_second  \
# 0         0  0.271174  0.014151         0.1         False          False
# 1         1  0.472229  0.139136         0.1          True          False
# 2         1  0.321438  0.015469         0.0         False          False
# 3         1  0.434531  0.103644         0.1          True          False
# 4         0  0.434531  0.015713         0.0         False          False
#
#    Pclass_third  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S  \
# 0          True       False      True       False       False        True
# 1         False        True     False        True       False       False
# 2          True        True     False       False       False        True
# 3         False        True     False       False       False        True
# 4          True       False      True       False       False        True
#
#    Initial_Master  Initial_Miss  Initial_Mr  Initial_Mrs  Initial_Other
# 0           False         False        True        False          False
# 1           False         False       False         True          False
# 2           False          True       False        False          False
# 3           False         False       False         True          False
# 4           False         False        True        False          False
